# %% [markdown]
# # Lecture du fichier

# %%
with open('real.txt') as file:
    fichier = file.read().splitlines()
fichier
# Out:
# ['479027832: 8 9 69 659 96 634',
#  '539373: 6 19 6 863',
#  '50830: 27 9 91 25 2',
#  '40213: 9 9 35 9 8 63 11 641',
#  '26324383: 7 9 8 7 414 471 185 8',
#  '11884578: 26 91 864 391 590 78',
#  '72700530602: 854 46 3 415 194 601',
#  '61748500: 74 5 896 689 5 66 53',
#  '108: 7 70 23 3 5',
#  '298900979: 4 57 9 144 35 14 979',
#  '1302118: 4 5 38 7 239 4 6 373 7',
#  '7238: 716 7 2 5 8',
#  '37856477: 728 65 8 4 74',
#  '189170: 7 269 76 698 93 3',
#  '7325: 73 2 5',
#  '345703232252: 3 8 4 6 9 128 6 4 4 8 2 52',
#  '9609860666: 208 91 230 2 666',
#  '24003: 5 99 9 4 4',
#  '9389450245: 47 329 5 2 66 3 92 628',
#  '959212: 4 4 2 516 472 4 25 708',
#  '363266: 2 8 7 7 3 2 6 8 302 863 3',
#  '4758: 74 19 51 14 1 1',
#  '1387500: 58 128 68 8 5 37',
#  '165768: 179 9 2 5 87 27 5',
#  '34729721751: 8 5 7 5 6 2 4 3 4 1 742 10',
#  '5544045: 621 83 875 5 9',
#  '23: 1 5 4 4 7',
#  '31938411: 53 264 23 20 195 411',
#  '50880: 253 6 4 4 5 5 54',
#  '36123702: 94 8 319 92 337',
# ...

# %% [markdown]
# # Nettoyage

# %%
fichier = [line.split(":") for line in fichier]
fichier
# Out:
# [['479027832', ' 8 9 69 659 96 634'],
#  ['539373', ' 6 19 6 863'],
#  ['50830', ' 27 9 91 25 2'],
#  ['40213', ' 9 9 35 9 8 63 11 641'],
#  ['26324383', ' 7 9 8 7 414 471 185 8'],
#  ['11884578', ' 26 91 864 391 590 78'],
#  ['72700530602', ' 854 46 3 415 194 601'],
#  ['61748500', ' 74 5 896 689 5 66 53'],
#  ['108', ' 7 70 23 3 5'],
#  ['298900979', ' 4 57 9 144 35 14 979'],
#  ['1302118', ' 4 5 38 7 239 4 6 373 7'],
#  ['7238', ' 716 7 2 5 8'],
#  ['37856477', ' 728 65 8 4 74'],
#  ['189170', ' 7 269 76 698 93 3'],
#  ['7325', ' 73 2 5'],
#  ['345703232252', ' 3 8 4 6 9 128 6 4 4 8 2 52'],
#  ['9609860666', ' 208 91 230 2 666'],
#  ['24003', ' 5 99 9 4 4'],
#  ['9389450245', ' 47 329 5 2 66 3 92 628'],
#  ['959212', ' 4 4 2 516 472 4 25 708'],
#  ['363266', ' 2 8 7 7 3 2 6 8 302 863 3'],
#  ['4758', ' 74 19 51 14 1 1'],
#  ['1387500', ' 58 128 68 8 5 37'],
#  ['165768', ' 179 9 2 5 87 27 5'],
#  ['34729721751', ' 8 5 7 5 6 2 4 3 4 1 742 10'],
#  ['5544045', ' 621 83 875 5 9'],
# ...

# %%
fichier = [
    (int(line[0]) , [int(number) for number in line[1].split()])
    for line in fichier
    ]
fichier
# Out:
# [(479027832, [8, 9, 69, 659, 96, 634]),
#  (539373, [6, 19, 6, 863]),
#  (50830, [27, 9, 91, 25, 2]),
#  (40213, [9, 9, 35, 9, 8, 63, 11, 641]),
#  (26324383, [7, 9, 8, 7, 414, 471, 185, 8]),
#  (11884578, [26, 91, 864, 391, 590, 78]),
#  (72700530602, [854, 46, 3, 415, 194, 601]),
#  (61748500, [74, 5, 896, 689, 5, 66, 53]),
#  (108, [7, 70, 23, 3, 5]),
#  (298900979, [4, 57, 9, 144, 35, 14, 979]),
#  (1302118, [4, 5, 38, 7, 239, 4, 6, 373, 7]),
#  (7238, [716, 7, 2, 5, 8]),
#  (37856477, [728, 65, 8, 4, 74]),
#  (189170, [7, 269, 76, 698, 93, 3]),
#  (7325, [73, 2, 5]),
#  (345703232252, [3, 8, 4, 6, 9, 128, 6, 4, 4, 8, 2, 52]),
#  (9609860666, [208, 91, 230, 2, 666]),
#  (24003, [5, 99, 9, 4, 4]),
#  (9389450245, [47, 329, 5, 2, 66, 3, 92, 628]),
#  (959212, [4, 4, 2, 516, 472, 4, 25, 708]),
#  (363266, [2, 8, 7, 7, 3, 2, 6, 8, 302, 863, 3]),
#  (4758, [74, 19, 51, 14, 1, 1]),
#  (1387500, [58, 128, 68, 8, 5, 37]),
#  (165768, [179, 9, 2, 5, 87, 27, 5]),
# ...

# %% [markdown]
# # Fonction qui calcule la multiplication et l'addition

# %%
def func_add_multiply(var_resultat: int,
                      var_new_nombre:int
                      ):
    """
    var_resultat : le resultat en cours 
    var_nombre : le nouveau nombre sur lequel on tente un opération pour creer un nouveau resultat

    """
    # print(var_resultat ,var_new_nombre)
    res_add = var_resultat + var_new_nombre
    res_mult = var_resultat * var_new_nombre

    # print(res_add,res_mult)
    return res_add,res_mult

# %% [markdown]
# # Foncion qui résout l'équation

# %%
def func_calcul_recursif(var_liste:list[int],
                         var_nombre_a_trouver:int,
                         var_ancien_res=None
                         ):

    # Si on a pas encore de résultat (début)
    if var_ancien_res is None :
        # Le premier résultat est le premier nombre de la liste
        var_ancien_res = var_liste[0]
        # On retire ce premier nombre pour éviter de le retraiter
        var_liste = var_liste[1:]


    # Si on arrive a la fin d'une branche
    if len(var_liste) == 0:
        # Si le résultat a été trouvé a la fin de la branche
        if var_ancien_res == var_nombre_a_trouver:
            # print("bravo, le resultat a été trouvé")
            return True
        # Si le résultat n'a pas été trouvé a la fin de la branche
        return False

    prochain_nombre = var_liste[0]  #Car on vide la liste au fur et a mesure
    
    # On récupere (ancien res + nouveau nombre) et (ancien res * nouveau nombre)
    nouveau_res_add, nouveau_res_mult = func_add_multiply(var_ancien_res, prochain_nombre)

    # Si me résultat a été trouvé, on arrete
    if func_calcul_recursif(var_liste[1:],var_nombre_a_trouver,nouveau_res_add):
        return True
    if func_calcul_recursif(var_liste[1:],var_nombre_a_trouver,nouveau_res_mult):
        return True

    # Si aucun resultat n'est le bon en ayant parcouru les deux branches
    return False

# %% [markdown]
# # Utilisation de la fonction récursive

# %%
sum(nb_a_trouver 
    for (nb_a_trouver,liste_nb)
    in fichier
    if func_calcul_recursif(liste_nb,nb_a_trouver))
# Out:
# 303876485655

# %% [markdown]
# # Correction

# %%
from itertools import product
liste2=[]
with open("real.txt") as fin:
    lines = fin.read().strip().split("\n")
somme = 0
for i, line in enumerate(lines):
    parts = line.split()
    value = int(parts[0][:-1])
    nums = list(map(int, parts[1:]))

    def test(combo):
        somme = nums[0]
        for i in range(1, len(nums)):
            if combo[i-1] == "+":
                somme += nums[i]
            else:
                somme *= nums[i]
        return somme

    for combo in product("*+", repeat=len(nums)-1):
        if test(combo) == value:
            # print(f"[{i:02}/{len(lines)}] WORKS", combo, value)
            somme += value
            break
somme
# Out:
# 303876485655
