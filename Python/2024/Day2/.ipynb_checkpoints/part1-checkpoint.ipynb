# %% [markdown]
# # Lecture du fichier

# %%
with open ("part1.txt") as file:
    fichier = file.readlines()
fichier
# Out:
# ['48 51 52 53 52\n',
#  '86 87 88 91 91\n',
#  '22 25 28 31 32 36\n',
#  '65 66 68 69 71 72 75 82\n',
#  '39 42 41 44 47\n',
#  '20 21 22 19 20 22 23 22\n',
#  '25 26 27 29 31 34 33 33\n',
#  '54 57 59 61 58 59 60 64\n',
#  '17 19 20 22 25 26 24 31\n',
#  '86 88 90 91 92 92 93 95\n',
#  '23 25 25 28 26\n',
#  '56 57 59 60 61 61 62 62\n',
#  '73 75 76 76 79 83\n',
#  '10 13 16 16 18 21 23 30\n',
#  '43 45 49 52 55 58 59 61\n',
#  '69 72 76 77 75\n',
#  '6 9 11 14 18 18\n',
#  '72 74 77 81 84 86 87 91\n',
#  '18 19 22 26 29 32 39\n',
#  '2 5 8 13 16 17\n',
#  '67 70 72 79 78\n',
#  '17 18 23 26 26\n',
#  '68 70 73 79 82 86\n',
#  '71 72 73 79 81 86\n',
#  '14 13 14 17 20 22 25 27\n',
#  '70 67 70 71 74 71\n',
#  '84 83 84 87 88 88\n',
#  '29 27 30 31 32 36\n',
#  '80 78 79 80 82 87\n',
#  '45 42 44 46 49 46 47 49\n',
#  '41 38 39 41 38 41 42 41\n',
#  '69 66 64 65 65\n',
#  '87 86 89 91 89 92 96\n',
#  '30 29 30 32 29 32 37\n',
#  '83 80 80 83 86 87 89 90\n',
#  '56 55 55 57 56\n',
# ...

# %% [markdown]
# # Mise en forme du fichier

# %%
fichier = [chain.replace("\n","") for chain in fichier]
fichier = [nb.split(" ") for nb in fichier]
fichier = [[int(nb) for nb in line] for line in fichier]
fichier
# Out:
# [[48, 51, 52, 53, 52],
#  [86, 87, 88, 91, 91],
#  [22, 25, 28, 31, 32, 36],
#  [65, 66, 68, 69, 71, 72, 75, 82],
#  [39, 42, 41, 44, 47],
#  [20, 21, 22, 19, 20, 22, 23, 22],
#  [25, 26, 27, 29, 31, 34, 33, 33],
#  [54, 57, 59, 61, 58, 59, 60, 64],
#  [17, 19, 20, 22, 25, 26, 24, 31],
#  [86, 88, 90, 91, 92, 92, 93, 95],
#  [23, 25, 25, 28, 26],
#  [56, 57, 59, 60, 61, 61, 62, 62],
#  [73, 75, 76, 76, 79, 83],
#  [10, 13, 16, 16, 18, 21, 23, 30],
#  [43, 45, 49, 52, 55, 58, 59, 61],
#  [69, 72, 76, 77, 75],
#  [6, 9, 11, 14, 18, 18],
#  [72, 74, 77, 81, 84, 86, 87, 91],
#  [18, 19, 22, 26, 29, 32, 39],
#  [2, 5, 8, 13, 16, 17],
#  [67, 70, 72, 79, 78],
#  [17, 18, 23, 26, 26],
#  [68, 70, 73, 79, 82, 86],
#  [71, 72, 73, 79, 81, 86],
#  [14, 13, 14, 17, 20, 22, 25, 27],
#  [70, 67, 70, 71, 74, 71],
#  [84, 83, 84, 87, 88, 88],
#  [29, 27, 30, 31, 32, 36],
#  [80, 78, 79, 80, 82, 87],
#  [45, 42, 44, 46, 49, 46, 47, 49],
#  [41, 38, 39, 41, 38, 41, 42, 41],
#  [69, 66, 64, 65, 65],
# ...

# %% [markdown]
# # Création de la fonction

# %%
# Cette fonction prends un rapport (list) en paramètre et vérifie :
    # - si elle est bien entièrement croissante/décroissante
    # - que les écarts entre les nombres successifs du rapport sont >1 et <3
def func_list_safe(liste):
    check = True
    nb_precedent= liste[0] 
    # Liste croissante
    if liste[1]>liste[0]: 
        for nb in liste[1:] :
            if nb < nb_precedent or not(1<=(nb-nb_precedent)<=3):
                check = False
                break
            nb_precedent = nb
            
    # Liste décroissante
    else:
        for nb in liste[1:] :
            if nb > nb_precedent or not(1<=(nb_precedent-nb)<=3):
                check = False
                break
            nb_precedent = nb
        
    return check

# %% [markdown]
# # Utilisation de la fonction

# %%
sum([1 for liste in fichier if func_list_safe(liste)])
# Out:
# 332
