# %% [markdown]
# # Import des librairies

# %% [markdown]
# # Lecture du fichier source

# %%
with open('real.txt') as fichier:
    file = fichier.read()

# %% [markdown]
# # Traitement

# %%
num_instructions = len(file)
num_floor = sum(
    1 if char=='(' 
    else -1 
    for char in file 
    )

num_floor
num_etage = 0
for index,char in enumerate(file):
    if char == '(':
        num_etage += 1
    else:
        num_etage -= 1
    if num_etage == -1:
        print(index+1)    
        break
# Out:
# 1783
