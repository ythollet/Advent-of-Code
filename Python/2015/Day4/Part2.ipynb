# %% [markdown]
# # Import des librairies

# %%
import hashlib

# %% [markdown]
# # Lecture du fichier source

# %%
with open('real.txt') as fichier:
    file = fichier.read()
file
# Out:
# 'yzbqklnj'

# %%
number = 1

while True:
    # Concaténation de la clé secrète avec le nombre
    message = file + str(number)

    # Calcul du hash MD5
    hash_result = hashlib.md5(message.encode()).hexdigest()

    # Vérifie si le hash commence par six zéros
    if hash_result.startswith('000000'):
        print(number)
        break

    number += 1
# Out:
# 9962624
